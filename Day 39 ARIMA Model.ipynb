# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Desktop\\Deep Learning with Prajwal'

# %%
# Read Data - Normal way

os.chdir('C:\\Users\\HP\\Downloads\\Batch 93 Day39\\')

# %%
df=pd.read_csv('Time_Series_Temp_Data.csv')
display(df)
# Out:
#          DATE   Temp  relative_humidity  wind_speed  Pressure
# 0    1/1/2020  -0.44               86.0        18.5    100.15
# 1    1/2/2020  -0.09               79.0        14.0    100.47
# 2    1/3/2020   2.95               82.0        12.0    100.64
# 3    1/4/2020  -0.80               86.0        15.0    100.75
# 4    1/5/2020  -7.95               74.5        15.0    101.06
# ..        ...    ...                ...         ...       ...
# 519  6/3/2021  18.55               83.5        12.0    101.14
# 520  6/4/2021  20.80               78.0        18.0    100.85
# 521  6/5/2021  22.75               71.5        13.5    100.76
# 522  6/6/2021  24.60               70.0        16.0    101.10
# 523  6/7/2021  26.10               57.0        19.5    101.24
#
# [524 rows x 5 columns]

# %%
# Display Data Type
df.dtypes
# Out:
# DATE                  object
# Temp                 float64
# relative_humidity    float64
# wind_speed           float64
# Pressure             float64
# dtype: object

# %%
'''Do you know 🧐 ? Prajwal, Parse Dates: use the parse_dates parameter to convince pandas to turn the date columns
   into real datetime types. By default, date columns are representd as object when loading data from a CSV file.
   The date column gets read as an object data type usig the default read_csv(): To read the date columnms correctly,
   we can use the argument parse_dates to specify a list of date columns.'''

# %%
# Read Data - Convert Date to Index columns

df=pd.read_csv('Time_Series_Temp_Data.csv',index_col='DATE',parse_dates=True)
df
# Out:
#              Temp  relative_humidity  wind_speed  Pressure
# DATE
# 2020-01-01  -0.44               86.0        18.5    100.15
# 2020-01-02  -0.09               79.0        14.0    100.47
# 2020-01-03   2.95               82.0        12.0    100.64
# 2020-01-04  -0.80               86.0        15.0    100.75
# 2020-01-05  -7.95               74.5        15.0    101.06
# ...           ...                ...         ...       ...
# 2021-06-03  18.55               83.5        12.0    101.14
# 2021-06-04  20.80               78.0        18.0    100.85
# 2021-06-05  22.75               71.5        13.5    100.76
# 2021-06-06  24.60               70.0        16.0    101.10
# 2021-06-07  26.10               57.0        19.5    101.24
#
# [524 rows x 4 columns]

# %%
df.dtypes
# Out:
# Temp                 float64
# relative_humidity    float64
# wind_speed           float64
# Pressure             float64
# dtype: object

# %%
# Update the Frequency to Date

df.index_frq='D'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 524 entries, 2020-01-01 to 2021-06-07
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Temp               524 non-null    float64
#  1   relative_humidity  524 non-null    float64
#  2   wind_speed         524 non-null    float64
#  3   Pressure           524 non-null    float64
# dtypes: float64(4)
# memory usage: 20.5 KB

# %%
# Check for NUll Record

df.isna().sum()
# Out:
# Temp                 0
# relative_humidity    0
# wind_speed           0
# Pressure             0
# dtype: int64

# %%
# Drop if any null records

df.dropna(inplace=True)
display(df.head(50))
# Out:
#              Temp  relative_humidity  wind_speed  Pressure
# DATE
# 2020-01-01  -0.44               86.0        18.5    100.15
# 2020-01-02  -0.09               79.0        14.0    100.47
# 2020-01-03   2.95               82.0        12.0    100.64
# 2020-01-04  -0.80               86.0        15.0    100.75
# 2020-01-05  -7.95               74.5        15.0    101.06
# 2020-01-06  -7.90               80.0        13.5    100.99
# 2020-01-07  -3.70               74.0        10.5    101.19
# 2020-01-08  -8.15               78.0        24.5    101.87
# 2020-01-09 -14.40               67.0        15.0    103.51
# 2020-01-10  -3.24               86.5        15.0    102.38
# 2020-01-11   2.95               96.0        17.0    101.58
# 2020-01-12  -6.80               82.0        18.0    102.03
# 2020-01-13  -9.19               84.5        10.5    103.14
# 2020-01-14  -7.55               89.5        12.0    102.47
# 2020-01-15  -3.00               90.5         8.5    101.85
# ...

# %%
df=pd.DataFrame(df['Temp'])
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# Plot the Trend and Seasonality

df['Temp'].rolling(30).mean().plot()
df['Temp'].rolling(30).std().plot()
df['Temp'].plot()
plt.show()

# %%
df['Temp'].rolling(7).mean().plot()
df['Temp'].rolling(7).std().plot()
df['Temp'].plot()
plt.show()

# %%
df['Temp'].rolling(30).mean().plot()
df['Temp'].rolling(30).std().plot()
df['Temp'].plot()
plt.show()

# %%
# Seasonal Decompose

from statsmodels.tsa.seasonal import seasonal_decompose
Decomp_results=seasonal_decompose(df)
Decomp_results.plot()
plt.show()

# %%
# Train Test Split

train=df.iloc[:510,0]
test=df.iloc[510:,0]

# %%
# Create PACF Graph
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_pacf(train,lags=50)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_pacf(train,lags=5)
plt.show()

# %%
plot_acf(train,lags=50)
plt.show()

# %%
# Identify best parameters 

from pmdarima import auto_arima
auto_arima(df,trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2846.718, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2929.050, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2931.026, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2930.983, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2927.135, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2845.685, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2856.303, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2882.045, Time=0.18 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2846.604, Time=0.30 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=2848.805, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2858.051, Time=0.22 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2848.587, Time=0.45 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=2844.520, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=2854.723, Time=0.04 sec
# ...

# %%
df
# Out:
#              Temp
# DATE
# 2020-01-01  -0.44
# 2020-01-02  -0.09
# 2020-01-03   2.95
# 2020-01-04  -0.80
# 2020-01-05  -7.95
# ...           ...
# 2021-06-03  18.55
# 2021-06-04  20.80
# 2021-06-05  22.75
# 2021-06-06  24.60
# 2021-06-07  26.10
#
# [524 rows x 1 columns]

# %%
# Create Model

from statsmodels.tsa.arima.model import ARIMA
A_Model=ARIMA(train,order=(1,1,2))
predictor=A_Model.fit()
predictor.summary()
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\HP\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\HP\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                   Temp   No. Observations:                  510
# Model:                 ARIMA(1, 1, 2)   Log Likelihood               -1378.671
# Date:                Wed, 17 Jul 2024   AIC                           2765.341
# ...

# %%
df
# Out:
#              Temp
# DATE
# 2020-01-01  -0.44
# 2020-01-02  -0.09
# 2020-01-03   2.95
# 2020-01-04  -0.80
# 2020-01-05  -7.95
# ...           ...
# 2021-06-03  18.55
# 2021-06-04  20.80
# 2021-06-05  22.75
# 2021-06-06  24.60
# 2021-06-07  26.10
#
# [524 rows x 1 columns]

# %%
# Prdiction for Training data set

Predicted_results=predictor.predict(start=len(train),end=len(train)+len(test)-1,typ='levels')
display(Predicted_results)
# Out:
# 2021-05-25    15.552138
# 2021-05-26    16.149254
# 2021-05-27    16.342371
# 2021-05-28    16.404829
# 2021-05-29    16.425028
# 2021-05-30    16.431561
# 2021-05-31    16.433674
# 2021-06-01    16.434358
# 2021-06-02    16.434579
# 2021-06-03    16.434650
# 2021-06-04    16.434673
# 2021-06-05    16.434681
# 2021-06-06    16.434683
# 2021-06-07    16.434684
# Freq: D, Name: predicted_mean, dtype: float64

# %%
# Display Prediction and Test values

result=pd.concat([test,Predicted_results ],axis=1)
display(result)
# Out:
#              Temp  predicted_mean
# 2021-05-25  19.14       15.552138
# 2021-05-26  21.95       16.149254
# 2021-05-27   8.44       16.342371
# 2021-05-28   7.65       16.404829
# 2021-05-29  10.90       16.425028
# 2021-05-30  11.85       16.431561
# 2021-05-31  14.45       16.433674
# 2021-06-01  18.20       16.434358
# 2021-06-02  18.30       16.434579
# 2021-06-03  18.55       16.434650
# 2021-06-04  20.80       16.434673
# 2021-06-05  22.75       16.434681
# 2021-06-06  24.60       16.434683
# 2021-06-07  26.10       16.434684

# %%
# Plot Graph

plt.plot(test,color='red',label='Actual Temp')
plt.plot(Predicted_results,color='blue',label='Predicted Temp')
plt.xlabel('Day')
plt.ylabel('Temp')
plt.legend()
plt.show()

# %%
# Caluculate the average

display(test.mean())
display(Predicted_results.mean())
# Out:
# 17.40571428571429
# 16.341511631990922

# %%
# Calculated RMSE

import math
from sklearn.metrics import mean_squared_error
rmse=math.sqrt(mean_squared_error(test,Predicted_results))
display(rmse)
# Out:
# 5.801290347340101

# %%
# Accuracy

from sklearn.metrics import r2_score
r2_score(test,Predicted_results)
# Out:
# -0.04399563092215031

# %%
'''Ok Data Analyst'''
# Out:
# 'Ok Data Analyst'
